# %%
def feet_to_inches(measurement):
    
    measurement_in_inches =  measurement*12
    return measurement_in_inches

feet_to_inches(1)
# Out:
# 12

# %%
number_chairs = 6

# %%
number_chairs
# Out:
# 6
